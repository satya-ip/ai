# %% [markdown]
# <a href="https://colab.research.google.com/github/satya-ip/ai-training/blob/main/Modern_AI_Pro_North_America_Essentials_April_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hey human learner: Welcome to the Level 1 of Modern AI Pro!
# *The best way to predict the future is to invent it.*
#
# It is going to be an amazing journey. From Team Mitra, we cannot be more excited for you guys to join us in exploring this amazing field. Here is all the key resources for this class.
#
# All the notebooks are linked from here. Additional code to run in your own environment is found here: https://github.com/balajivis/modernaipro
#
# LLM Arena: https://huggingface.co/spaces/lmsys/chatbot-arena-leaderboard

# %% [markdown]
# ![neliti_AI_in_teaching_and_learning_4K_ultrarestics_28f38230-ca84-411c-ad90-af1e1000e1b4.png](data:image/png;base64,...)

# %% [markdown]
# ## Day 0: Foundation

# %% [markdown]
# **4:30 - 5pm: Intro to Modern AI**: The path Towards AGI [Slides](https://docs.google.com/presentation/d/1hXcru7QqAy7SkvVoNnODCfvb5o9R0wtf4Eik1xGSZJc/edit?usp=sharing)
#
# **5 - 6:30 PM:** Lab Session for Technical Setup + practicing prompt engineering with local LLMs (80 min)
#
# 1. [Install Miniconda](https://docs.anaconda.com/miniconda/miniconda-install/)
# 2. [Setup the path in Windows](https://eduand-alvarez.medium.com/setting-up-anaconda-on-your-windows-pc-6e39800c1afb)  || on Mac do **export PATH="\$HOME/miniconda3/bin:$PATH"** on the terminal
# 3. [Setup split screen in Windows](https://support.lenovo.com/us/en/solutions/ht513508) || on Mac, use the spaces feature.
# 4. [Install Ollama](https://ollama.com/download)
# 5. [Install Cursor](https://www.cursor.com/). Backup is [VSCode](https://code.visualstudio.com/download)
# 6. [Install Git](https://git-scm.com/book/en/v2/Getting-Started-Installing-Git) and setup its path
# 7. *In your terminal, do the following:* **conda create -n modernai python==3.11**
# 8. (optional) **conda activate modernai**
# 9. **ollama pull llama3.2**
# 10. **git clone https://github.com/balajivis/modernaipro**
# 11. **cd modernaipro** (cd modernaipro-main if you are downloading directly from the repo)
# 12. (optional) **pip install -r requirements.txt** [don't worry about uvloop]
# 13. Sign up & get API keys/token at **[Groq](https://console.groq.com/)**,**Kaggle, HuggingFace**

# %% [markdown]
# ## Day 1: Building ML Models

# %% [markdown]
# ###***Morning (8:30 - 12 noon PST)***
# **Objective**: To provide hands-on experience with fundamental machine learning (ML) concepts and techniques, focusing on data preprocessing, visualization, model training, and ethics in AI.
# 0. Intro to Machine Learning
# 1. [Classification with Resonsible AI](https://colab.research.google.com/drive/1KdOjCip0w5DR3Kiw5IEB3gkJZlzpV4We) [Income Class Prediction.ipynb]
# 2. [Regression analysis notebook](https://colab.research.google.com/drive/1CEgw080U0FarmFIwQLBtbusgmyBdYB5f#scrollTo=VXkVxmD5hixL) [Home Price Prediction.ipynb]
#
# 3. [Slides 1](https://drive.google.com/file/d/1BEZ_l9C7V35Y-4vKBUk3AW4n9YLbiXj-/view) [Modern_AI_Pro_Arvind_-_Module_1 - PPT]
#
# 4. [Slides 2](https://docs.google.com/presentation/d/1NsEE97cccyYxGB2wuatdAq0Kq7hNcz6CuUlyvr9xAe8/edit#slide=id.g2be5a1179c2_0_1200) [Session 3_ Home Prices Prediction.pptx]
#
#
# ###***Noon - 12:45pm -- Break***
#
# ###**12:45pm -- 3pm**:
#
# 1. [Slides 1](https://docs.google.com/presentation/d/1aVakLkyuHwE3vt4wdTRqZrpRGeItqdbNAg0s5ycjs8Q/edit?usp=sharing) [ Modern AI Pro_ Running first LLM.pptx]
#
# 2. [Slides 2](https://docs.google.com/presentation/d/1aVakLkyuHwE3vt4wdTRqZrpRGeItqdbNAg0s5ycjs8Q/edit?usp=sharing) [Modern AI Pro_ Running first LLM - PPT]
#
# 3. [How LLMs work](https://colab.research.google.com/drive/1gCjPmLF64S8qK3kCPmKfAWzy4f06oqaR#scrollTo=eS1CpZKoG9C0) [Understanding LLMs.ipynb]
# 4. Local LLM with Ollama
# 5. [First LLM Call on Colab](https://colab.research.google.com/drive/14I39CnLNSZYekRVzArEuE2Q1Sryhov2i#scrollTo=BF0-EoHaRS4W) [First LLM.ipynb]
# 6.[First chatbot](https://colab.research.google.com/drive/1q14coEFNdJ6rgk8Nd0sZ4ymnufbDlqaq?usp=sharing) [First Chatbot.ipynb]
# 7. Prompt Engineering theory and practice
#
# ###***3 - 3:15pm Break***
#
# ###**3:15pm -- 4:30pm**
# 1. [Slides](https://docs.google.com/presentation/d/1bYrhKzT6TuU4v6ebeWz9uq1pZP12PA0Ur1pxpA05ulA/edit?usp=sharing) [Modern AI Pro_ Building Agents.pptx]
# 2. [Perplexity clone: LLM with real time data](https://colab.research.google.com/drive/1mK9R-aJFWwREhuH99if9okpjxBhw2rt3?usp=sharing) [Real time info with LLM.ipynb]
# 3. [LLM with memory](https://colab.research.google.com/drive/1nIQbid1SBPCkoQhjysgbXGClLZ4I8sy1?usp=sharing) [Chatbot with memory.ipynb]
#
# **Further explorations**
# 0. [Intro to Gradio](https://www.gradio.app/guides/quickstart)
# 1. [Deploying Gradio in Nginx on the server](https://www.gradio.app/guides/running-gradio-on-your-web-server-with-nginx)
# 2. [Beginner's guide to Ollama](https://ronaldsvilcins.com/2024/03/02/a-beginners-guide-to-ollama/)
# 3. [Understanding next token prediction](https://medium.com/@akash.kesrwani99/understanding-next-token-prediction-concept-to-code-1st-part-7054dabda347)
# 4. [LLM with Multimodality](https://colab.research.google.com/drive/1EUu7lS6r6DUEqoxnlobiOh5FHQuCm2r6)
# 5. [Summarizing a Video with Whisper API and LLM](https://colab.research.google.com/drive/17qFwmGKsRxhav7gB2JZy9NolK_9furAT#scrollTo=HxnStJ_PrDib) (15 min)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Day 2: NLP to RAG

# %% [markdown]
# ### Morning (8:30am - 12noon)
# [Slides 1](https://drive.google.com/file/d/1jUsewggM8pk5t7XYJZpCkQmruqLh_G_o/view)
# [Slides 2](https://drive.google.com/file/d/19UqxFiHKHoAZnwPSCDTE7E3wD6HVOWiR/view)
# [Slides 3](https://docs.google.com/presentation/d/1BETtFncM602LN-xGia3h7yp6xXM7jAow-xKhDTH0sg8/edit#slide=id.g1e2ee25a6cc_0_0)
# 1. Theory of Natural Language Processing
# 1. Understanding embedding models
# 1. [Categories of NLP Problems](https://docs.google.com/presentation/d/17iM6BO76T21ebPlZjjs7Msl5QmDgLqA6LPSXdba61BE/edit?usp=sharing) (15 min)
# 2. [Introducing Hugging Face Pipeline and NLP Problems](https://colab.research.google.com/drive/1bRZYvajrSV_k1AgH_Je1O4TWfpNvRU0P#scrollTo=qa1rqZ7mIVPM) (15 min)
# 5. [Praciting Similiarity search with Vector DB](https://colab.research.google.com/drive/1cQr0ssoXcYxhJ5MvhtoYwmG67g3l0P5W?usp=sharing)
# 3. Vector Databases
# 1. Why do we need RAG?
#
# 1. Understanding the business side of Gen AI![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Afternoon (12:45 - 4:30pm)
# 1. [Advanced Chatbot](https://colab.research.google.com/drive/1npEnRSYXB4GC5nbRPowhkPCG7S6fhBRb#scrollTo=WqWmxbtp08Tw)
# 6. [Access control](https://colab.research.google.com/drive/1FarVX93keIA35dvMHr7k6FXBu1rTpv97)
#
#
# Break
# 1. [Summarizing a Video with Whisper API and LLM](https://colab.research.google.com/drive/17qFwmGKsRxhav7gB2JZy9NolK_9furAT#scrollTo=HxnStJ_PrDib) (15 min)
# 5. Document extraction into Vector DB
# 5. Building a power RAG based chatbot on Streamlit
# 5. [RAG with SQL](https://colab.research.google.com/drive/1patliw_XCH-3eKJVrfVcjF8nLyPy1Mb7)
# 6. [RAG with SQL 2](https://colab.research.google.com/drive/18ZyyCfpPDnGOQNw0aevpfx-ZjSstwFsi)
#
# **Further Explorations**:
# 1. [Document summarization & analysis](https://colab.research.google.com/drive/1zwJZLN63f6thjlhmZYiocIyUe_ViEYzl?usp=sharing)
